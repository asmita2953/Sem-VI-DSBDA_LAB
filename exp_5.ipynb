# %% [raw]
# Perform the following operations on any open source dataset
# Provide summary statistics (mean, median, minimum, maximum, standard deviation) for  a dataset (age, income etc.) with numeric variables grouped by one of the qualitative  (categorical) variable. For example, if your categorical variable is age groups and quantitative  variable is income, then provide summary statistics of income grouped by the age groups.  Create a list that contains a numeric value for each response to the categorical variable. Write a Python program to display some basic statistical details like percentile, mean,  standard deviation etc. of the species of ‘Iris-setosa’, ‘Iris-versicolor’ and ‘Iris-verginica’ of  iris.csv dataset.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("3.data.csv")

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df['age'].min()
# Out:
# 17

# %%
df['age'].max()
# Out:
# 90

# %%
df['age'].mean()
# Out:
# 38.64358543876172

# %%
df['age'].median()
# Out:
# 37.0

# %%
df['age'].std()
# Out:
# 13.71050993444322

# %%
df.groupby(['age','income']).count()
# Out:
#             workclass  fnlwgt  education  educational-num  marital-status  \
# age income
# 17  <=50K         595     595        595              595             595
# 18  <=50K         862     862        862              862             862
# 19  <=50K        1050    1050       1050             1050            1050
#     >50K            3       3          3                3               3
# 20  <=50K        1112    1112       1112             1112            1112
# ...               ...     ...        ...              ...             ...
# 88  <=50K           5       5          5                5               5
#     >50K            1       1          1                1               1
# 89  <=50K           2       2          2                2               2
# 90  <=50K          42      42         42               42              42
#     >50K           13      13         13               13              13
#
#             occupation  relationship  race  gender  capital-gain  \
# ...

# %%
df.groupby(['age','income']).min()
# Out:
#                    workclass  fnlwgt   education  educational-num  \
# age income
# 17  <=50K                  ?   19752        10th                3
# 18  <=50K                  ?   20057        10th                3
# 19  <=50K                  ?   20469        10th                1
#     >50K                   ?  142738        12th                4
# 20  <=50K                  ?   19410        10th                1
# ...                      ...     ...         ...              ...
# 88  <=50K            Private   30102     7th-8th                4
#     >50K    Self-emp-not-inc  263569        11th                7
# 89  <=50K                  ?   29106        10th                6
# 90  <=50K                  ?   39824        10th                2
#     >50K                   ?   46786  Assoc-acdm                9
#
#                 marital-status       occupation   relationship  \
# age income
# 17  <=50K   Married-civ-spouse                ?        Husband
# ...

# %%
df.groupby(['age','income']).max()
# Out:
#                    workclass   fnlwgt     education  educational-num  \
# age income
# 17  <=50K          State-gov   806316  Some-college               10
# 18  <=50K          State-gov   761006  Some-college               14
# 19  <=50K        Without-pay  1047822  Some-college               13
#     >50K             Private   323605  Some-college               10
# 20  <=50K          State-gov   745817  Some-college               14
# ...                      ...      ...           ...              ...
# 88  <=50K   Self-emp-not-inc   206291  Some-college               15
#     >50K    Self-emp-not-inc   263569          11th                7
# 89  <=50K            Private   152839     Bachelors               13
# 90  <=50K   Self-emp-not-inc   347074  Some-college               15
#     >50K    Self-emp-not-inc   313986   Prof-school               15
#
#                 marital-status        occupation relationship   race gender  \
# age income
# ...

# %%
df.groupby(['age','income']).mean()
# Out:
# /tmp/ipykernel_22343/1562288969.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['age','income']).mean()
#                    fnlwgt  educational-num  capital-gain  capital-loss  \
# age income
# 17  <=50K   179157.852101         6.685714     81.245378     33.302521
# 18  <=50K   193421.075406         8.220418     76.163573     37.852668
# 19  <=50K   204866.963810         9.091429     99.438095     42.700952
#     >50K    222377.666667         7.333333   9702.666667      0.000000
# 20  <=50K   197962.343525         9.342626     66.997302     35.776079
# ...                   ...              ...           ...           ...
# 88  <=50K   126735.000000        11.400000      0.000000    363.200000
#     >50K    263569.000000         7.000000   6418.000000      0.000000
# ...

# %%
df.groupby(['age','income']).median()
# Out:
# /tmp/ipykernel_22343/1398202380.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['age','income']).median()
#               fnlwgt  educational-num  capital-gain  capital-loss  \
# age income
# 17  <=50K   167658.0              7.0           0.0           0.0
# 18  <=50K   177613.0              9.0           0.0           0.0
# 19  <=50K   192307.5              9.0           0.0           0.0
#     >50K    200790.0              8.0       14084.0           0.0
# 20  <=50K   190281.5             10.0           0.0           0.0
# ...              ...              ...           ...           ...
# 88  <=50K   141646.0             13.0           0.0           0.0
#     >50K    263569.0              7.0        6418.0           0.0
# ...

# %%
df.groupby(['age','income']).std()
# Out:
# /tmp/ipykernel_22343/2137963530.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['age','income']).std()
#                    fnlwgt  educational-num  capital-gain  capital-loss  \
# age income
# 17  <=50K   101243.296009         0.957188   1407.535432    232.467309
# 18  <=50K   112046.448155         1.437882   1194.025643    245.870731
# 19  <=50K   116351.515261         1.394263   1515.336478    269.259342
#     >50K     92345.754837         3.055050   8415.890050      0.000000
# 20  <=50K   105724.045468         1.314072   1070.613636    250.178117
# ...                   ...              ...           ...           ...
# 88  <=50K    75696.395565         4.615192      0.000000    812.139889
#     >50K              NaN              NaN           NaN           NaN
# ...

# %%
#Iris Dataset
df1=pd.read_csv("5-8-13-14.iris.csv")
df1.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df1
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df1.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
setosa_data = df1[df1['variety'] == 'Setosa']

# %%
Setosa_stats = setosa_data.describe()
Setosa_stats
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %%
versicolor_data = df1[df1['variety'] == 'Versicolor']
versicolor_stats = versicolor_data.describe()
versicolor_stats
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
virginica_data = df1[df1['variety'] == 'Virginica']
virginica_stats = virginica_data.describe()
virginica_stats
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000
